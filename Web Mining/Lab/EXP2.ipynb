# %% [markdown]
# # Breadth-First-Search

# %%
# Importing Beautiful Soup
from bs4 import BeautifulSoup
import requests

# %%
#Importing libraries from URLlib
from urllib.request import urljoin
from urllib.request import urlparse

# %%
# Storing urls with same domain entered in the URL
links_intern = set()
# Storing urls with different domain from the entered URL
links_extern = set()
input_url=input("Please enter the link to be searched: ")
depth=int(input("Please enter the depth level of the search: "))
# Out:
# Please enter the link to be searched: https://vit.ac.in/
# Please enter the depth level of the search: 1

# %%
# Method for crawling a url at next level
def level_crawler(input_url):
    temp_urls=set()
    #Parsing the entered URL
    current_url_domain=urlparse(input_url).netloc
    # Creates beautiful soup object to extract html tags
    beautiful_soup_object = BeautifulSoup(requests.get(input_url).content, "lxml")
    # Access all anchor tags from input
    # url page and divide them into internal
    # and external categories
    for anchor in beautiful_soup_object.findAll("a"):
        href = anchor.attrs.get("href")
        if(href!="" or href!=None):
            href=urljoin(input_url, href)
            href_parsed=urlparse(href)
            href=href_parsed.scheme
            href+="://"
            href+=href_parsed.netloc
            href+=href_parsed.path
            final_parsed_href=urlparse(href)
            is_valid=bool(final_parsed_href.scheme) and bool(final_parsed_href.netloc)
            if is_valid:
                if current_url_domain not in href and href not in links_extern:
                    print("External (Not from entered link) - {}".format(href))
                    links_extern.add(href)
                if current_url_domain in href and href not in links_intern:
                    print("Internal (From entered link) - {}".format(href))
                    links_intern.add(href)
                    temp_urls.add(href)
    return temp_urls

# %%
if(depth == 0):
    print("Intern - {}".format(input_url))
elif(depth == 1):
    level_crawler(input_url)
else:
    queue = []
    queue.append(input_url)
    for j in range(depth):
        for count in range(len(queue)):
            url = queue.pop(0)
            urls = level_crawler(url)
            for i in urls:
                queue.append(i)
# Out:
# Internal (From entered link) - https://vit.ac.in/
# Internal (From entered link) - https://viteee.vit.ac.in/
# Internal (From entered link) - http://chennai.vit.ac.in/
# External (Not from entered link) - https://vitap.ac.in/
# External (Not from entered link) - https://vitbhopal.ac.in/
# Internal (From entered link) - https://vit.ac.in
# Internal (From entered link) - https://vit.ac.in/about-vit
# Internal (From entered link) - https://vit.ac.in/about/vision-mission
# Internal (From entered link) - https://vit.ac.in/vit-milestones
# Internal (From entered link) - https://vit.ac.in/about/leadership
# Internal (From entered link) - https://vit.ac.in/governance
# Internal (From entered link) - https://vit.ac.in/about/administrative-offices
# Internal (From entered link) - https://vit.ac.in/about/infrastructure
# Internal (From entered link) - https://vit.ac.in/about/ranking-and-accreditation
# Internal (From entered link) - https://vit.ac.in/about/sustainability
# Internal (From entered link) - https://vit.ac.in/true-green
# Internal (From entered link) - https://vit.ac.in/about/community-outreach
# Internal (From entered link) - https://vit.ac.in/about/communityradio
# Internal (From entered link) - https://vit.ac.in/all-news-archieved
# Internal (From entered link) - https://vit.ac.in/all-events
# Internal (From entered link) - https://vit.ac.in/national-institutional-ranking-framework-nirf
# Internal (From entered link) - https://vit.ac.in/mhrdugc
# Internal (From entered link) - http://careers.vit.ac.in/
# Internal (From entered link) - https://vit.ac.in/about/news-letter
# Internal (From entered link) - https://vit.ac.in/academics/home
# Internal (From entered link) - https://vit.ac.in/sites/default/files/academic/Academic-Regulations.pdf
# Internal (From entered link) - https://vit.ac.in/vit-rank/
# Internal (From entered link) - https://vit.ac.in/sitemap/
# Internal (From entered link) - https://vit.ac.in/academics/iqac
# External (Not from entered link) - http://www.mhrdnats.gov.in/
# Internal (From entered link) - https://vit.ac.in/sites/default/files/footer_menu_doc/FormatGuidelines%20%283%29.doc
# Internal (From entered link) - https://vit.ac.in/sites/default/files/Student-Code-of-Conduct.pdf
# Internal (From entered link) - http://intranet.vit.ac.in/
# Internal (From entered link) - https://peopleorbit.vit.ac.in//
# Internal (From entered link) - https://webmail.vit.ac.in/
# Internal (From entered link) - https://careers.vit.ac.in/
# External (Not from entered link) - https://www.vitaa.org/
# Internal (From entered link) - https://vit.ac.in/contactus
# Internal (From entered link) - https://vit.ac.in/guesthouse/
# External (Not from entered link) - https://www.facebook.com/vituniversity/
# Internal (From entered link) - https://campustour.vit.ac.in

# %% [markdown]
# # Depth First Search

# %%
#Importing Beautiful Soup library
import requests
from bs4 import BeautifulSoup

# %%
def search_dfs(base, path, visited, max_depth=3, depth=0):
    if depth < max_depth:
        try:
            soup = BeautifulSoup(requests.get(base + path).text, "html.parser")
            for link in soup.find_all("a"):
                href = link.get("href")
                if href not in visited:
                    visited.add(href)
                    print(f"at depth {depth}: {href}")
                    if href.startswith("http"):
                        search_dfs(href, "", visited, max_depth-1, depth + 1)
                    else:
                        search_dfs(base, href, visited, max_depth-1, depth + 1)
        except:
            pass

# %%
link=input("Enter the link to search from: ")
search_dfs(link, "", set([link]))
# Out:
# Enter the link to search from: https://vit.ac.in/
# at depth 0: #main-content
# at depth 1: https://viteee.vit.ac.in/
# at depth 1: http://chennai.vit.ac.in/
# at depth 1: https://vitap.ac.in/
# at depth 1: https://vitbhopal.ac.in/
# at depth 1: /
# at depth 1: #
# at depth 1: https://vit.ac.in
# at depth 1: https://vit.ac.in/about-vit
# at depth 1: https://vit.ac.in/about/vision-mission
# at depth 1: https://vit.ac.in/vit-milestones
# at depth 1: https://vit.ac.in/about/leadership
# at depth 1: https://vit.ac.in/governance
# at depth 1: https://vit.ac.in/about/administrative-offices
# at depth 1: https://vit.ac.in/about/infrastructure
# at depth 1: https://vit.ac.in/about/ranking-and-accreditation
# at depth 1: https://vit.ac.in/about/sustainability
# at depth 1: https://vit.ac.in/true-green
# at depth 1: https://vit.ac.in/about/community-outreach
# at depth 1: https://vit.ac.in/about/communityradio
# at depth 1: https://vit.ac.in/all-news-archieved
# at depth 1: https://vit.ac.in/all-events
# at depth 1: https://vit.ac.in/national-institutional-ranking-framework-nirf
# at depth 1: https://vit.ac.in/mhrdugc
# at depth 1: http://careers.vit.ac.in/
# at depth 1: https://vit.ac.in/about/news-letter
# at depth 1: https://vit.ac.in/academics/home
# at depth 1: https://vit.ac.in/sites/default/files/academic/Academic-Regulations.pdf
# at depth 1: https://vit.ac.in/programmes-offered-1
# at depth 1: https://vit.ac.in/programmes-offered-2021-22
# at depth 1: https://vit.ac.in/programmes-offered-2020-21
# at depth 1: https://vit.ac.in/schools
# at depth 1: https://vit.ac.in/academics/ffcs
# at depth 1: https://vit.ac.in/academics/library
# at depth 1: https://vit.ac.in/academics-feedback
# at depth 1: https://vit.ac.in/admissions/overview
# at depth 1: https://vit.ac.in/admissions/programmes-offered
# at depth 1: https://vit.ac.in/all-courses/ug
# at depth 1: https://vit.ac.in/all-courses/pg
# at depth 1: https://vit.ac.in/admissions/research
# at depth 1: https://vit.ac.in/admissions/research/Integrated_Ph.D
# at depth 1: https://vit.ac.in/admissions/research/phd
# at depth 1: https://vit.ac.in/admissions/international
# at depth 1: https://vit.ac.in/stars-support-advancement-rural-students-0
# at depth 1: https://vit.ac.in/placements/overview
# at depth 1: https://vit.ac.in/career-development-centre
# at depth 1: https://vit.ac.in/placements/superdreamoffers
# at depth 1: https://vit.ac.in/placements/dreamoffers
# at depth 1: https://vit.ac.in/placements/internship
# at depth 1: https://vit.ac.in/placements/statistics
# at depth 1: https://vit.ac.in/placements/pat-Office
# at depth 1: https://vit.ac.in/placements/contact-us
# at depth 1: https://vit.ac.in/InternationalRelations
# at depth 1: https://vit.ac.in/internationalrelations/itp
# at depth 1: https://vit.ac.in/internationalrelations/partneruniversities
# at depth 1: https://vit.ac.in/internationalrelations/sap
# at depth 1: https://vit.ac.in/admissions/international/overview
# at depth 1: https://vit.ac.in/academics-more/Contact us
# at depth 1: https://vit.ac.in/research
# at depth 1: https://vit.ac.in/research/academic
# at depth 1: https://vit.ac.in/research/sponsored-research
# at depth 1: https://vit.ac.in/iprcell
# at depth 1: https://vit.ac.in/research/centers-list
# at depth 1: https://vit.ac.in/campuslife/overview
# at depth 1: https://vit.ac.in/campuslife/fests
# at depth 1: https://vit.ac.in/campuslife/studentswelfare
# at depth 1: https://vit.ac.in/campus-category/Clubs
# at depth 1: https://vit.ac.in/campus-category/Chapters
# at depth 1: https://vit.ac.in/campus-category/Campus-Events
# at depth 1: https://vit.ac.in/campus-category/Counselling-Division
# at depth 1: https://vit.ac.in/campus-category/grievancecell
# at depth 1: https://vit.ac.in/campus-category/Student-Council
# at depth 1: https://vit.ac.in/campuslife/sports
# at depth 1: https://vit.ac.in/campuslife/hostels
# at depth 1: https://vit.ac.in/campuslife/healthservices
# at depth 1: https://vit.ac.in/campuslife/otheramenities
# at depth 1: https://vit.ac.in/detailview/green-vit
# at depth 1: https://vit.ac.in/vitol/
# at depth 1: javascript:void(0)
# at depth 1: https://vit.ac.in/academics/coe
# at depth 1: https://vit.ac.in/transcripts-alumni
# at depth 1: https://vit.applydirect.org/student
# at depth 1: https://applications.wes.org/required-documents/Search/Result?cId=2&eId=38&iNm=Vellore%20Institute%20of%20Technology%20%28VIT%29&cNm=Bachelor%20of%20Applied%20Arts&iSec=University%20Education&iSub=Bachelor%27s%20Degree%20Programs&comp=1&isEca=False
# at depth 1: https://www.wes.org/advisor-blog/send-electronic-academic-records/
# at depth 1: https://vit.ac.in/files/e-SANAD-Notification.pdf
# at depth 1: https://web.vit.ac.in/CertificateVerification/login
# at depth 1: https://vit.ac.in/coe-email-contacts
# at depth 1: https://vit.ac.in/centers/asc
# at depth 1: http://www.vittbi.com/#/
# at depth 1: https://vtop.vit.ac.in/
# at depth 1: https://vit.ac.in/guest-house
# at depth 1: https://vit.ac.in/redressal
# at depth 1: https://vit.ac.in/hotels-in-vellore
# at depth 1: https://mail.google.com/
# at depth 1: http://intranet.vit.ac.in
# at depth 1: https://vit.ac.in/sites/default/files/SBST_Freshers_App.rar
# at depth 1: https://vit.ac.in/anti-ragging-committee
# at depth 1: https://vit.ac.in/capability-enhancement-scheme
# at depth 1: https://vit.ac.in/sites/default/files/FormatGuidelines.doc
# at depth 1: https://vit.ac.in/internal-complaints-committee
# at depth 1: https://vit.ac.in/alumni_progression
# at depth 1: https://vit.ac.in/academics/transcripts
# at depth 1: https://vit.ac.in/instruction
# at depth 1: https://www.campusinteraction.com/
# at depth 1: https://vtop.vit.ac.in/vtop/initialProcess
# at depth 1: https://vit.ac.in/alumni-events
# at depth 1: https://www.vitaa.org/page/Distinguished-Alumni-Award-Winners.dz
# at depth 1: https://vit.ac.in/sites/default/files/vitaa/e-Tracks-2020/index.html
# at depth 1: https://vit.ac.in/detailview/alumni-photo-gallery
# at depth 1: http://www.vitaa.org/
# at depth 1: https://vit.ac.in/alumni-office-contact
# at depth 1: https://campustour.vit.ac.in/
# at depth 1:
# at depth 1:  https://vit.ac.in/vit-rank/
# at depth 1:  VIT - the only Private Institution of India in Shanghai Ranking 2021
# at depth 1:  QS-Rank 2021
# at depth 1: https://www.facebook.com/VITuniversity/
# at depth 1: https://twitter.com/vit_univ
# at depth 1: https://www.linkedin.com/school/vellore-institute-of-technology/
# at depth 1: https://www.instagram.com/vellore_vit/
# at depth 1: https://www.youtube.com/c/VITUniversityVellore
# at depth 1: https://vit.ac.in/vit-school-agricultural-innovations-and-advanced-learning-vaial/national-farmers-day-2021
# at depth 1: https://vit.ac.in/general/workshop-disaster-risk-reduction-strategies-and-challenges
# at depth 1: https://vit.ac.in/vit-business-school-vit-bs/vit-business-school-management-fest-2022
# at depth 1: https://vit.ac.in/school-electronics-engineering-sense/second-international-conference-artificial-intelligence
# at depth 1: https://vit.ac.in/school-mechanical-engineeringsmec/27th-national-conference-internal-combustion-engines-and
# at depth 1: https://photos.app.goo.gl/1AHjtNup4SeJknyx8
# at depth 1: https://web.vit.ac.in/phd
# at depth 1: https://admissions.vit.ac.in/payment/freshers
# at depth 1: https://admissions.vit.ac.in/pgapplication/
# at depth 1: https://vit.ac.in/all-courses/pg/master-of-business-administration
# at depth 1: http://info.vit.ac.in/phd-vlr-dec-2021/index.asp
# at depth 1: http://info.vit.ac.in/phd-che-dec-2021/index.asp
# at depth 1: http://info.vit.ac.in/phd-ap-dec-2021/index.asp
# at depth 1: https://photos.app.goo.gl/2m9LiPAnrJyP2HuV7
# at depth 1: https://smel-nabl.vit.ac.in/
# at depth 1: https://vit.ac.in/phd-vacancy-positions-list
# at depth 1: https://vit.ac.in/Ariia-2021/
# at depth 1: https://vit.ac.in/convocation
# at depth 1: https://www.youtube.com/watch?v=JzDMjJIqM_s
# at depth 1: https://vit.ac.in/detailview/36th-convocation-photos
# at depth 1: /national-institutional-ranking-framework-nirf
# at depth 1: https://www.vidyalakshmi.co.in/Students/
# at depth 1: /ranking
# at depth 1: https://vit.ac.in/vit-rank
# at depth 1: https://vit.ac.in/vit-institution-eminence-ioe
# at depth 1: https://vit.ac.in/ariia-award
# at depth 1: https://vit.ac.in/qs-ranks-vit-one-among-top-12-institutions-india-engineering-and-technology
# at depth 1: https://vit.ac.in/vit-only-private-institution-india-shanghai-ranking-2021
# at depth 1: /academics/InternationalRelations
# at depth 1: placements/statistics
# at depth 1: https://vit.ac.in/vit-university-sets-record-limca-book-records
# at depth 1: /admission-overview
# at depth 1: /all-news
# at depth 1: https://vit.ac.in/159th-birthday-celebration-swami-vivekananda-0
# at depth 1: https://vit.ac.in/vit-student-won-gold-medal-archery-event-5th-pykka-national-games-held-jaipur
# at depth 1: https://vit.ac.in/36th-annual-convocation-0
# at depth 1: https://vit.ac.in/agrivaial-imparts-training-students-about-use-drones-organic-farming
# at depth 1: vit-alumnus-recognized-best-performing-ias-officer
# at depth 1: vit-sae-team-rotorfpv
# at depth 1: 5-teams-vit-qualify-finals-nasscom-–-ibm-all-india-hackathon
# at depth 1: virtual-track-competitions-communications-award
# at depth 1: team-roverx-creation-labs-vit-vellore-has-achieved-new-milestone-year-scoring-9036-its-system
# at depth 1: 3d-printing-play-major-role-mitigating-spread-covid-19-say-researchers-vit
# at depth 1: article-published-hindu-business-line-co-authored-vit-alumnus-and-niti-aayog’s
# at depth 1: students-robovitics-vit-have-designed-and-manufactured-3d-printed-prototypes-spare-parts-medical
# at depth 1: https://vit.ac.in/galleries
# at depth 1: http://campustour.vit.ac.in/
# at depth 1: https://vit.ac.in/video
# at depth 1: https://vit.ac.in/campus-hostel/hostels
# at depth 1: http://info.vit.ac.in/guesthouse/
# at depth 1: https://vit.ac.in/vit-rank/
# at depth 1: https://vit.ac.in/sitemap/
# at depth 1: https://vit.ac.in/academics/iqac
# at depth 1: http://www.mhrdnats.gov.in/
# at depth 1: https://vit.ac.in/sites/default/files/footer_menu_doc/FormatGuidelines%20%283%29.doc
# at depth 1: https://vit.ac.in/sites/default/files/Student-Code-of-Conduct.pdf
# at depth 1: http://intranet.vit.ac.in/
# at depth 1: https://peopleorbit.vit.ac.in//
# at depth 1: https://webmail.vit.ac.in/
# at depth 1: https://careers.vit.ac.in/
# at depth 1: https://www.vitaa.org/
# at depth 1: https://vit.ac.in/contactus
# at depth 1: https://vit.ac.in/guesthouse/
# at depth 1: https://www.facebook.com/vituniversity/
# at depth 1: https://campustour.vit.ac.in

# %% [markdown]
# # (Challenging Task)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\dell\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\dell\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: sniffio in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: async-generator>=1.9 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dell\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\dell\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\dell\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\dell\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\dell\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\dell\appdata\roaming\python\python39\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\dell\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %% [markdown]
# # Chennai........

# %%
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\dell\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: crayons in c:\users\dell\anaconda3\lib\site-packages (from webdriver-manager) (0.4.0)
# Requirement already satisfied: configparser in c:\users\dell\anaconda3\lib\site-packages (from webdriver-manager) (5.2.0)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from webdriver-manager) (2.26.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.2)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\DELL\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-12-6cae888399d0>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://chennai.vit.ac.in/about/contactus/') 
chennai = driver.find_elements_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/article/div[2]/div[1]') 
chennai_list = [] 
for p in range (len(chennai)): 
    chennai_list.append(chennai[p].text) 
    print(chennai_list[p])
# Out:
# VIT Chennai
# Vandalur – Kelambakkam Road
# Chennai – 600 127
# 044 3993 1555
# Fax : 044 3993 2555
# admin.chennai@vit.ac.in
# Admissions Office
# Dr. T. Palani Rajan
# Assistant Director (Admissions)
# VIT Chennai Campus,
# Vandalur-Kelambakkam Road,
# Chennai-600127,
# Tamil Nadu, India.
# +91 44 3993 1003
# Fax : +91-44 3993 2555
# admin.chennai@vit.ac.in
# admissions.chennai@vit.ac.in
# Director – Placement & Training
# Dr. Arockia Selvakumar &
# Prof. V. Anantha Krishnan
# Assistant Director – Placements and Training
# VIT Chennai Campus, Chennai
# Vandalur – Kelambakkam road,
# Chennai-600127
#  chennai.pat@vit.ac.in
# International Relations
# Dr. Syed Ibrahim &
# Dr. Nithya Venkatesan
# Assistant Director – International Relations
# VIT Chennai Campus,
# Vandalur-Kelambakkam Road,
# Chennai-600127,
# Tamil Nadu, India.
# +91-44-39931392
#   ir4@vit.ac.in
#   ir5@vit.ac.in
# <ipython-input-13-026f1fa7f661>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   chennai = driver.find_elements_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/article/div[2]/div[1]')

# %% [markdown]
# # vellore

# %%
driver.get('https://vit.ac.in/contactus') #ignore this cell 
vellore = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div[2]/div[1]/div/div[2]/div/div/section/div/div/div[1]/div/div/div/table[1]/tbody') 
vellore_list=[]
for p in range(len(vellore)): 
    vellore_list.append(vellore [p].text)
    print(vellore_list[p])
# Out:
# VIT
# Vellore Campus
# Vellore - 632 014
# Tamilnadu, India
# Tel: 91-416-2243091 / 93
# Fax: 91-416-2243092
# 91-416-2240411 VIT
# Chennai Campus
# Vandalur - Kelambakkam Road
# Chennai - 600 127
# Ph : 044 3993 1555
# Fax : 044 3993 2555
# admin.chennai@vit.ac.in
# Admissions Office
# Dr.G.Kalaichelvan
# Director - UG Admissions
# Vellore Institute of Technology
# Vellore - 632 014,
# Tamil Nadu, India.
# Telephone: 044-462-77555
# Fax: +91-416-224 5544, 224 0411
# Email: ugadmission@vit.ac.in Admissions Office
# Dr. Ramasubramanian V
# Director - PG Admissions
# Vellore Institute of Technology
# Vellore - 632 014,
# Tamil Nadu, India.
# Phone: + 91-416-220 2188
# Fax: +91-416-224 5544, 224 9955
# Email: pgadmission@vit.ac.in
# Dr.V.Samuel Rajkumar
# Director - Career Development Centre (CDC)
# Vellore Institute of Technology
# Vellore - 632 014.
# Tamil Nadu.
# Tel: 0416 - 2202846
# Fax: 91-416-2243092, 91-416-224 0411
# placement@vit.ac.in
# International Relations Office
# Dr. C. Vijayakumar
# Director - International Relations
# Vellore Institute of Technology
# Vellore - 632 014.
# Tamil Nadu, India
# Tel: 91-416-224 3118
# Fax: 91-416-2243092
# director.ir@vit.ac.in
# vijay@vit.ac.in
# <ipython-input-14-9b00bc89d244>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   vellore = driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div[2]/div[1]/div/div[2]/div/div/section/div/div/div[1]/div/div/div/table[1]/tbody')

# %% [markdown]
# # AMRAVATI

# %%
driver.get('https://vitap.ac.in/contact-us/') # ignore this cell 
Andhra= driver.find_elements_by_xpath('/html/body/div/div/div/section[2]/div/div/div/div/div/div[1]/div/div[1]') 
Andhra_list = [] 
for p in range(len(Andhra)): 
    Andhra_list.append(Andhra[p].text) 
    print(Andhra_list[p])
# Out:
# For Admission
# Assistant Director (Admissions)
# Room No. SRB-G30
# VIT-AP University
# (Beside AP Secretariat)
# Near Vijayawada, 522 237
# Andhra Pradesh
#
# admission@vitap.ac.in
# 0863 2370444
#  7901091283
# General Information
# The Registrar
# VIT-AP University
# (Beside AP Secretariat)
# Near Vijayawada, 522 237
# Andhra Pradesh
#
# info@vitap.ac.in
# Admin. Office at Hyderabad
# VIT-AP University
# Admin. Office
# 4th Floor
# Bansal Pride Building
# Near YSR Statue
# Madhapur
# HYDERABAD – 500 081
# Telangana State
# adminoffice@vitap.ac.in
# 040-29559555
# 7901311658
# <ipython-input-15-7a794861cd19>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Andhra= driver.find_elements_by_xpath('/html/body/div/div/div/section[2]/div/div/div/div/div/div[1]/div/div[1]')

# %% [markdown]
# # BHOPAL

# %%
driver.get('https://vitbhopal.ac.in/contacts/')
Bhopal = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div/div') 
Bhopal_list = []
for p in range(len(Bhopal)): 
    Bhopal_list.append(Bhopal[p].text) 
    print(Bhopal_list[p])
# Out:
# Location
# VIT Bhopal University,
# Bhopal-Indore Highway
# Kothrikalan, Sehore
# Madhya Pradesh - 466114
# Phone
# +91 756 0254 500/501/502
# WhatsApp
# 73586 13555, 73586 21555
# Email
# info@vitbhopal.ac.in
# Office Hours
# Mon - Fri: 8:30 AM - 5:00 PM
# VIT Bhopal Admission Contacts
# BBA - 7024181823
# B.Sc- 7828921560
# Int.M.Sc-7024181826
# Int.M.Tech-7024181830
# M.Tech- 7024181820
# MCA- 7024181821
# B.Tech- 7024240869
# Payment failure issues
# 9384670522, 7024181840, 7024181841
# Send an email feescollection@vitbhopal.ac.in, sdc@vitbhopal.ac.in along with application no
# VITEEE Counselling 2021
# Contact Us
# Get in Touch
# <ipython-input-16-cd9b497dda3c>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Bhopal = driver.find_elements_by_xpath('/html/body/div[3]/div/div/div/div')
